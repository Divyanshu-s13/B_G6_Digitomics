# %% [markdown]
# # Digitomics - Student Digital Behaviour Analysis
# ## Notebook 1: Data Import & Initial Exploration

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('../data/raw/student_digital_behaviour_data.csv')

# %%
df.head(100)
# Out:
#     student_id       country development_level  poverty_rate_percent  \
# 0            1         Qatar        Developing                 16.30
# 1            2           USA         Developed                  8.75
# 2            3        Mexico        Developing                 23.64
# 3            4        Canada         Developed                 14.51
# 4            5     Sri Lanka    Underdeveloped                 62.28
# 5            6       Vietnam        Developing                 30.70
# 6            7  Saudi Arabia        Developing                 18.41
# 7            8         Japan         Developed                  6.56
# 8            9  Saudi Arabia        Developing                 18.41
# 9           10       Germany         Developed                 10.99
# 10          11       Denmark         Developed                  5.21
# 11          12         India        Developing                 21.08
# 12          13    Bangladesh    Underdeveloped                 37.93
# ...
